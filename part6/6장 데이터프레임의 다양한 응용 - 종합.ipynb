# %% [markdown]
# # 6장 데이터프레임의 다양한 응용
# - 데이터프레임에 함수를 매핑하는 방법, 데이터를 집계하는 그룹연산, 데이터프레임을 합치거나 다양한 구조로 변경하는 방법

# %% [markdown]
# 1 함수 매핑
# - 데이터 프레임의 개별 원소를 특정 함수에 일대일 대응시키는 과정
# - 사용자 지정 함수를 적용할 수 있기 때문에 판다스 기본 함수로 처리하기 어려운 복잡한 연산을 데이터프레임 등 판다스 객체에 적용한는 가능

# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age','fare']] # ['age','fare'] 열을 가져왔다

df['ten'] = 10
df.head()
# Out:
#     age     fare  ten
# 0  22.0   7.2500   10
# 1  38.0  71.2833   10
# 2  26.0   7.9250   10
# 3  35.0  53.1000   10
# 4  35.0   8.0500   10

# %%
# 사용자 함수 정의

def add_10(n) : # 10을 더하는 함수 # def는 Python에서 함수를 정의할 때 사용
    return n+ 10

# %%
def add_two_obj(a, b):
    return a + b

# %%
add_10(10)
# Out:
# 20

# %%
add_two_obj(10,10)
# Out:
# 20

# %%
# 시리즈 객체에 적용
sr1 = df['age'].apply(add_10) # df['age']를 통해 DataFrame df의 'age' 열을 선택하여 시리즈 형태의 데이터를 가져옵니다.
sr1.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
# 시리즈 객체와 숫자에 적용 : 2개의 인수(시리즈 + 숫자)
sr2 = df['age'].apply(add_two_obj, b = 10) # a=df['age'] 의 모든 원소 는 10
sr2.head()
#add_two_obj 함수는 두 개의 매개변수 a와 b를 받습니다. 여기서 a는 DataFrame의 'age' 열 값이 되고, b는 10이 전달
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %%
# 람다 함수 활용 : 시리즈 객체에 적용
sr3 = df['age'].apply(lambda x:add_10(x))
sr3.head()
# Out:
# 0    32.0
# 1    48.0
# 2    36.0
# 3    45.0
# 4    45.0
# Name: age, dtype: float64

# %% [markdown]
# 3가지 케이스 모두 age 열의 각 원소에 10을 더한 값을 가진 같은 크기의 시리즈가 된다. 또한 age열의 이름이 시리즈 객체의 이름으로
# 유지 되는 것을 확인할 수 있음

# %% [markdown]
# 데이터프레임 원소에 함수 매핑

# %%
titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age','fare']] # 행은 비어있으면 행을 다 가져온는 것이다
df.tail() #df.tail()은 DataFrame df의 마지막 5개 행을 출력하는 명령어입니다.
# Out:
#       age   fare
# 886  27.0  13.00
# 887  19.0  30.00
# 888   NaN  23.45
# 889  26.0  30.00
# 890  32.0   7.75

# %%
df_map = df.applymap(add_10)
display(df_map.tail())
df_map1 = df.applymap(add_two_obj, b = 4)
display(df_map1.tail())
df_map2 = df.applymap(lambda x : add_10(x))
display(df_map1.tail())
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_12648\2914553348.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_map = df.applymap(add_10)
#       age   fare
# 886  37.0  23.00
# 887  29.0  40.00
# 888   NaN  33.45
# 889  36.0  40.00
# 890  42.0  17.75
# C:\Users\705-8\AppData\Local\Temp\ipykernel_12648\2914553348.py:3: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_map1 = df.applymap(add_two_obj, b = 4)
#       age   fare
# 886  31.0  17.00
# 887  23.0  34.00
# 888   NaN  27.45
# 889  30.0  34.00
# 890  36.0  11.75
# C:\Users\705-8\AppData\Local\Temp\ipykernel_12648\2914553348.py:5: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_map2 = df.applymap(lambda x : add_10(x))
#       age   fare
# 886  37.0  23.00
# 887  29.0  40.00
# 888   NaN  33.45
# 889  36.0  40.00
# 890  42.0  17.75

# %% [markdown]
# 1-2 시리즈 객체에 함수 매핑

# %%
df.head()
# Out:
#           연월일   당일종가  전일종가     시가     고가     저가     거래량   연
# 0  2018-07-02  10100   600  10850  10900  10000  137977  02
# 1  2018-06-29  10700   300  10550  10900   9990  170253  29
# 2  2018-06-28  10400   500  10900  10950  10150  155769  28
# 3  2018-06-27  10900   100  10800  11050  10500  133548  27
# 4  2018-06-26  10800   350  10900  11000  10700   63039  26

# %%
# 사용자 함수 정의
def missing_value(series) : # 시리즈로 인수를 전달
    return series.isnull() # 불린시리즈를 반환 # NaN 값이 없으면 False # False인 경우는 해당 위치의 값이 누락되지 않았음을 의미

# %%
# 데이터프레임의 각 열(시리즈)을 이수로 전달하면 데이터프레임을 반환
result = df.apply(missing_value, axis=0)
result.head()
# Out:
#      연월일   당일종가   전일종가     시가     고가     저가    거래량      연
# 0  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False

# %%
# 사용자 함수 정의
def min_max(x) : # 최대값 - 최소값 
    return x.max() - x.min()

# %%
result = df.apply(min_max, axis=0) # age에서 최대 - 최소 fare 에서 최대 - 최소
result
# Out:
# age      79.5800
# fare    512.3292
# ten       0.0000
# add      79.5800
# dtype: float64

# %%
df = titanic.loc[:,['age','fare']]
df['ten'] = 10
df.head()
# Out:
#     age     fare  ten
# 0  22.0   7.2500   10
# 1  38.0  71.2833   10
# 2  26.0   7.9250   10
# 3  35.0  53.1000   10
# 4  35.0   8.0500   10

# %%
add_two_obj(1,2)
# Out:
# 3

# %%
# 데이터프레임의 2개 열을 선택하여 적용
# x=df, a=df['age'], b=df['ten']
df['add'] = df.apply(lambda x:add_two_obj(x['age'],x['ten']), axis=1)
df.head()
# Out:
#     age     fare  ten   add
# 0  22.0   7.2500   10  32.0
# 1  38.0  71.2833   10  48.0
# 2  26.0   7.9250   10  36.0
# 3  35.0  53.1000   10  45.0
# 4  35.0   8.0500   10  45.0

# %% [markdown]
# 1-3 데이터프레임 객체에 함수 매핑

# %%
# 각 열의 NaN 찾기 - 데이터프레임 전달하면 데이터프레임을 반환
#함수를 매핑(mapping)한다는 것은 데이터 구조(예: DataFrame, Series) 전체에 특정 함수를 적용하는 것을 의미

# %%
# 각 열의 NaN 개수 반환 - 데이터프레임 전달하면 데이터프레임을 반환
def missing_value(x):
    return x.isnull()

# %%
# 데이터 프레임 전달하면 시리즈 반환 
def missing_count(x):
    return missing_value(x).sum() # t1 f 0 해서 다 더한 값을 낸다
#result에는 DataFrame df의 각 열에 대한 누락된 값의 개수가 저장

# %%
# 데이터프레임 전달하면 값을 반환
def total_number_missing(x):
    return missing_count(x).sum() #

# %%
result_df = df.pipe(missing_value)
result_df.head()
# Out:
#      age   fare    ten    add
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False  False  False
# 4  False  False  False  False

# %%
result_series = df.pipe(missing_count)
result_series
# Out:
# age     177
# fare      0
# ten       0
# add     177
# dtype: int64

# %%
result_value = df.pipe(total_number_missing)
print(type(result_value))
result_value
# Out:
# <class 'numpy.int64'>
# 354

# %% [markdown]
# # 2 열 재구성

# %% [markdown]
# ##2-1 열 순서 변경
#
# - 데이터프레임의 열 순서를 변경하는 방법은 열 이름을 원하는 순서대로 정리해서 리스트를 만들고 데이터프레임에서 열을 다시 선택하는 방식으로 열 순서를 바꿀 수 있음

# %%
df = titanic.loc[0:4,'survived':'age']
df
# Out:
#    survived  pclass     sex   age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0

# %%
columns = list(df.columns)
columns
# Out:
# ['survived', 'pclass', 'sex', 'age']

# %%
 # 열이름의 리스트 만들기
columns_sorted = sorted(columns) # 알파벳 순으로 정렬
print(columns_sorted)
df_sorted = df[columns_sorted] # df_sorted = df[['age','pclass','sex','survived']]
df_sorted
# Out:
# ['age', 'pclass', 'sex', 'survived']
#     age  pclass     sex  survived
# 0  22.0       3    male         0
# 1  38.0       1  female         1
# 2  26.0       3  female         1
# 3  35.0       1  female         1
# 4  35.0       3    male         0

# %%
print(columns)
columns_reversed = list(reversed(columns)) # 리스트의 순서를 역순으로 만듭니다
print(columns_reversed)

df_reversed = df[columns_reversed]
df_reversed
# Out:
# ['survived', 'pclass', 'sex', 'age']
# ['age', 'sex', 'pclass', 'survived']
#     age     sex  pclass  survived
# 0  22.0    male       3         0
# 1  38.0  female       1         1
# 2  26.0  female       3         1
# 3  35.0  female       1         1
# 4  35.0    male       3         0

# %%
columns_customed=['sex', 'pclass', 'age', 'survived']
df_customed = df[columns_customed]
df_customed
# Out:
#       sex  pclass   age  survived
# 0    male       3  22.0         0
# 1  female       1  38.0         1
# 2  female       3  26.0         1
# 3  female       1  35.0         1
# 4    male       3  35.0         0

# %% [markdown]
# # 2 열 분리

# %%
df = titanic.loc[0:4,'survived':'age']
X = df[['pclass','sex','age']]
y = df['survived']
display(X)
display(y)
# Out:
#    pclass     sex   age
# 0       3    male  22.0
# 1       1  female  38.0
# 2       3  female  26.0
# 3       1  female  35.0
# 4       3    male  35.0
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
df = titanic.loc[0:4,'survived':'age']
y = df['survived']
del df['survived'] # 삭제하고 남은 3개를 넣는다
x = df
display(X)
display(y)
# Out:
#    pclass     sex   age
# 0       3    male  22.0
# 1       1  female  38.0
# 2       3  female  26.0
# 3       1  female  35.0
# 4       3    male  35.0
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
import pandas as pd 

df = pd.read_excel('c:/sample_data/주가데이터.xlsx')
df.head()
# Out:
#          연월일   당일종가  전일종가     시가     고가     저가     거래량
# 0 2018-07-02  10100   600  10850  10900  10000  137977
# 1 2018-06-29  10700   300  10550  10900   9990  170253
# 2 2018-06-28  10400   500  10900  10950  10150  155769
# 3 2018-06-27  10900   100  10800  11050  10500  133548
# 4 2018-06-26  10800   350  10900  11000  10700   63039

# %%
df.dtypes
# Out:
# 연월일     datetime64[ns]
# 당일종가             int64
# 전일종가             int64
# 시가               int64
# 고가               int64
# 저가               int64
# 거래량              int64
# dtype: object

# %%
df.iloc[0]['연월일']
# Out:
# Timestamp('2018-07-02 00:00:00')

# %%
# 연 월 일 데이터 분리하기 
df['연월일'] = df['연월일'].astype('str')
dates = df['연월일'].str.split('-')
dates.head() # 리스트 형태로 반환된다
# Out:
# 0    [2018, 07, 02]
# 1    [2018, 06, 29]
# 2    [2018, 06, 28]
# 3    [2018, 06, 27]
# 4    [2018, 06, 26]
# Name: 연월일, dtype: object

# %%
dates.str.get(0).head() # 시리즈의 문자열 리스트 인덱싱 series 객체. str.get(인덱스)
# Out:
# 0    2018
# 1    2018
# 2    2018
# 3    2018
# 4    2018
# Name: 연월일, dtype: object

# %%
# 분리된 정보를 각각 새로운열에 담아서 df에 추가하기
df['연'] = dates.str.get(0)
df['월'] = dates.str.get(1)
df['일'] = dates.str.get(2)
df.head()
# Out:
#           연월일   당일종가  전일종가     시가     고가     저가     거래량     연   월   일
# 0  2018-07-02  10100   600  10850  10900  10000  137977  2018  07  02
# 1  2018-06-29  10700   300  10550  10900   9990  170253  2018  06  29
# 2  2018-06-28  10400   500  10900  10950  10150  155769  2018  06  28
# 3  2018-06-27  10900   100  10800  11050  10500  133548  2018  06  27
# 4  2018-06-26  10800   350  10900  11000  10700   63039  2018  06  26

# %% [markdown]
# # 3 필터링
# - 시리즈 또는 데이터프레임의 데이터 중에서 특정 조건식을 만족하는 원소만 따로 추출하는 개념

# %% [markdown]
# # 3-1 불린 인덱싱
#
# -시리즈 객체에 어떤 조건식을 적용하면 각 원소에 참 거짓을 판별해 불린 값으로 구성된 시리즈를 반환

# %%
titanic = sns.load_dataset('titanic')

# 나이가 10-19세 10대인 승객만 따로 선택
mask1 = (titanic['age'] >= 10) & (titanic['age'] < 20)
mask1[:10]
# 조건식을 이용하면 데이터 만족하는 값에는 True 그렇지 않은 값엔 False 
# 9번 인덱스가 True
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9     True
# Name: age, dtype: bool

# %%
df_teenage = titanic.loc[mask1, :] # 마스크1의 0 false 가 다 들어감
df_teenage.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 9          1       2  female  14.0      1      0   30.0708        C  Second
# 14         0       3  female  14.0      0      0    7.8542        S   Third
# 22         1       3  female  15.0      0      0    8.0292        Q   Third
# 27         0       1    male  19.0      3      2  263.0000        S   First
# 38         0       3  female  18.0      2      0   18.0000        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 9   child       False  NaN    Cherbourg   yes  False
# 14  child       False  NaN  Southampton    no   True
# 22  child       False  NaN   Queenstown   yes   True
# 27    man        True    C  Southampton    no  False
# 38  woman       False  NaN  Southampton    no  False

# %%
mask2 = (titanic['age'] < 10) & (titanic['sex'] == 'female')
mask1[:11]
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# Name: age, dtype: bool

# %%
df_female_under10 = titanic.loc[mask2, :] # mask2 에서 전체를 다 가져와 주세요
df_female_under10.head()
# Out:
#      survived  pclass     sex  age  sibsp  parch     fare embarked   class  \
# 10          1       3  female  4.0      1      1  16.7000        S   Third
# 24          0       3  female  8.0      3      1  21.0750        S   Third
# 43          1       2  female  3.0      1      2  41.5792        C  Second
# 58          1       2  female  5.0      1      2  27.7500        S  Second
# 119         0       3  female  2.0      4      2  31.2750        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 10   child       False    G  Southampton   yes  False
# 24   child       False  NaN  Southampton    no  False
# 43   child       False  NaN    Cherbourg   yes  False
# 58   child       False  NaN  Southampton   yes  False
# 119  child       False  NaN  Southampton    no  False

# %%
# 나이가 10세 미만(0~9세) 또는 60세 이상인 승객의 age, sex, alone 열만 선택
mask3 = (titanic['age'] < 10) | (titanic['age'] >= 60)
df_female_under10_morethan60 = titanic.loc[mask3, ['age', 'sex', 'alone']]
df_female_under10_morethan60.head()
# Out:
#      age     sex  alone
# 7    2.0    male  False
# 10   4.0  female  False
# 16   2.0    male  False
# 24   8.0  female  False
# 33  66.0    male   True

# %% [markdown]
# ## 3-2 isin() 메소드 활용

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
#IPython 디스플레이 설정 변경 - 출력할 최대 열의 개수
pd.set_option('display.max_columns',10)

# %%
# sibsp - 함께 탑승한 형제 또는 배우자의 수가 3, 4, 5 인 승객만 따로 추출 -불린 인덱싱
mask3 = titanic['sibsp'] == 3
mask4 = titanic['sibsp'] == 4
mask5 = titanic['sibsp'] == 5
df_boolean = titanic[mask3 | mask4 | mask5]
df_boolean.head()
# Out:
#     survived  pclass     sex   age  sibsp  ...  adult_male  deck  embark_town  \
# 7          0       3    male   2.0      3  ...       False   NaN  Southampton
# 16         0       3    male   2.0      4  ...       False   NaN   Queenstown
# 24         0       3  female   8.0      3  ...       False   NaN  Southampton
# 27         0       1    male  19.0      3  ...        True     C  Southampton
# 50         0       3    male   7.0      4  ...       False   NaN  Southampton
#
#    alive  alone
# 7     no  False
# 16    no  False
# 24    no  False
# 27    no  False
# 50    no  False
#
# [5 rows x 15 columns]

# %%
# isin() 메서드 활용하여 동일한 조건으로 추출 #sibsp 에 345 들어있는 값들의 인덱스만 True로 해준다
isin_filter = titanic['sibsp'].isin([3, 4, 5])
df.isin = titanic[isin_filter]
df.isin.head()
# Out:
#     survived  pclass     sex   age  sibsp  ...  adult_male  deck  embark_town  \
# 7          0       3    male   2.0      3  ...       False   NaN  Southampton
# 16         0       3    male   2.0      4  ...       False   NaN   Queenstown
# 24         0       3  female   8.0      3  ...       False   NaN  Southampton
# 27         0       1    male  19.0      3  ...        True     C  Southampton
# 50         0       3    male   7.0      4  ...       False   NaN  Southampton
#
#    alive  alone
# 7     no  False
# 16    no  False
# 24    no  False
# 27    no  False
# 50    no  False
#
# [5 rows x 15 columns]

# %% [markdown]
# # 4 데이터프레임 합치기
#
# ### 데이터가 여러 군데 나누어져 있을 때 하나로 합치거나 데이터를 연결해야 하는 경우 사용

# %% [markdown]
# ## 4-1 데이터 프레임 연결
# - concat

# %%
# 데이터프레임 만들기 
import pandas as pd
df1 = pd.DataFrame({'a': ['a0', 'a1', 'a2', 'a3'],
                    'b': ['b0', 'b1', 'b2', 'b3'],
                    'c': ['c0', 'c1', 'c2', 'c3']},
                    index = [0, 1, 2, 3])

df2 = pd.DataFrame({'a': ['a2', 'a3', 'a4', 'a5'],
                    'b': ['b2', 'b3', 'b4', 'b5'],
                    'c': ['c2', 'c3', 'c4', 'c5'],
                    'd': ['d2', 'd3', 'd4', 'd5']},
                    index = [2, 3, 4, 5])
df1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3

# %%
df2
# Out:
#     a   b   c   d
# 2  a2  b2  c2  d2
# 3  a3  b3  c3  d3
# 4  a4  b4  c4  d4
# 5  a5  b5  c5  d5

# %%
result1 = pd.concat([df1, df2])
result1
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 2  a2  b2  c2   d2
# 3  a3  b3  c3   d3
# 4  a4  b4  c4   d4
# 5  a5  b5  c5   d5

# %%
result1.loc[2] # 하나만 선택되어야 정상인데 인덱스가 2인게 2개라서 2개 선택됨, 이렇게 되면 오류가 생길 수 도 있음
# Out:
#     a   b   c    d
# 2  a2  b2  c2  NaN
# 2  a2  b2  c2   d2

# %%
result1.reset_index()
# Out:
#    index   a   b   c    d
# 0      0  a0  b0  c0  NaN
# 1      1  a1  b1  c1  NaN
# 2      2  a2  b2  c2  NaN
# 3      3  a3  b3  c3  NaN
# 4      2  a2  b2  c2   d2
# 5      3  a3  b3  c3   d3
# 6      4  a4  b4  c4   d4
# 7      5  a5  b5  c5   d5

# %%
# ignore_index = True 옵션 설정하기
# 인덱스 재설정
result2 = pd.concat([df1, df2], ignore_index = True)
result2
# Out:
#     a   b   c    d
# 0  a0  b0  c0  NaN
# 1  a1  b1  c1  NaN
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3  NaN
# 4  a2  b2  c2   d2
# 5  a3  b3  c3   d3
# 6  a4  b4  c4   d4
# 7  a5  b5  c5   d5

# %%
# 2개의 데이터프레임을 좌우 열 방향으로 이러 붙이듯 연결하기
result3 = pd.concat([df1, df2], axis=1)
result3
# Out:
#      a    b    c    a    b    c    d
# 0   a0   b0   c0  NaN  NaN  NaN  NaN
# 1   a1   b1   c1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   a2   b2   c2   d2
# 3   a3   b3   c3   a3   b3   c3   d3
# 4  NaN  NaN  NaN   a4   b4   c4   d4
# 5  NaN  NaN  NaN   a5   b5   c5   d5

# %%
# ignore_index = True 옵션 설정하기 자기가 알아서 숫자값으로 배열됨
result3 = pd.concat([df1, df2], axis=1, ignore_index = True)
result3
# Out:
#      0    1    2    3    4    5    6
# 0   a0   b0   c0  NaN  NaN  NaN  NaN
# 1   a1   b1   c1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   a2   b2   c2   d2
# 3   a3   b3   c3   a3   b3   c3   d3
# 4  NaN  NaN  NaN   a4   b4   c4   d4
# 5  NaN  NaN  NaN   a5   b5   c5   d5

# %%
# join ='inner' 옵션 적용하기(교집합), 인덱스를 기준으로
result3_in = pd.concat([df1, df2], axis=1, join ='inner')
result3_in
# Out:
#     a   b   c   a   b   c   d
# 2  a2  b2  c2  a2  b2  c2  d2
# 3  a3  b3  c3  a3  b3  c3  d3

# %%
# 시리즈 만들기

sr1 = pd.Series(['e0', 'e1', 'e2', 'e3'], name='e')
sr2 = pd.Series(['f0', 'f1', 'f2'], name='f', index = [3, 4, 5])
sr3 = pd.Series(['g0', 'g1', 'g2', 'g3'], name='g')
sr1
# Out:
# 0    e0
# 1    e1
# 2    e2
# 3    e3
# Name: e, dtype: object

# %%
sr2
# Out:
# 3    f0
# 4    f1
# 5    f2
# Name: f, dtype: object

# %%
sr3
# Out:
# 0    g0
# 1    g1
# 2    g2
# 3    g3
# Name: g, dtype: object

# %%
#df1 과 sr1을 좌우 열 방향으로 연결하기
result4= pd.concat([df1, sr1], axis =1)
result4
# Out:
#     a   b   c   e
# 0  a0  b0  c0  e0
# 1  a1  b1  c1  e1
# 2  a2  b2  c2  e2
# 3  a3  b3  c3  e3

# %%
# df2 과 sr2을 좌우 열 방향으로 연결하기
result5 = pd.concat([df2, sr2], axis =1, sort=True)
result5
# Out:
#     a   b   c   d    f
# 2  a2  b2  c2  d2  NaN
# 3  a3  b3  c3  d3   f0
# 4  a4  b4  c4  d4   f1
# 5  a5  b5  c5  d5   f2

# %%
result6 = pd.concat([sr1, sr3], axis =1)
result6
# Out:
#     e   g
# 0  e0  g0
# 1  e1  g1
# 2  e2  g2
# 3  e3  g3

# %%
result7= pd.concat([sr1, sr3], axis =0) # 좌우로 합쳤을때는 컬럼이 많아져서 데이터 프레임 # 근데 시리즈가 위아래로 붙을때는 시리즈로
result7
# Out:
# 0    e0
# 1    e1
# 2    e2
# 3    e3
# 0    g0
# 1    g1
# 2    g2
# 3    g3
# dtype: object

# %% [markdown]
# # 4-2 데이터프레임 병함
# - merge() 함수 어떤 기준에 의해 두 데이터프레임을 병합하는 개념
# - 기준이 되는 열이나 인덱스를 key 라고 부르고 키는  양쪽의 데이터프레임이 반드시 존재

# %%
# Ipython 디스플레이 설정 변경
pd.set_option('display.max_columns', 10) # 출력할 열의 최대 개수
pd.set_option('display.max_colwidth', 20) # 출력할 열의 너비
pd.set_option('display.unicode.east_asian_width', True) # 유니코드 사용 너비 조정
 
# 주식 데이터를 가져와서 데이터프레임 만들기
df1 = pd.read_excel('C:/sample_data/stock price.xlsx')
df2 = pd.read_excel('C:/sample_data/stock valuation.xlsx')

df1
# Out:
#        id    stock_name          value   price
# 0  128940      한미약품   59385.666667  421000
# 1  130960        CJ E&M   58540.666667   98900
# 2  138250    엔에스쇼핑   14558.666667   13200
# 3  139480        이마트  239230.833333  254500
# 4  142280  녹십자엠에스     468.833333   10200
# 5  145990        삼양사   82750.000000   82000
# 6  185750        종근당   40293.666667  100500
# 7  192400    쿠쿠홀딩스  179204.666667  177500
# 8  199800          툴젠   -2514.333333  115400
# 9  204210  모두투어리츠    3093.333333    3475

# %%
df2
# Out:
#        id              name           eps     bps        per       pbr
# 0  130960            CJ E&M   6301.333333   54068  15.695091  1.829178
# 1  136480              하림    274.166667    3551  11.489362  0.887074
# 2  138040    메리츠금융지주   2122.333333   14894   6.313806  0.899691
# 3  139480            이마트  18268.166667  295780  13.931338  0.860437
# 4  145990            삼양사   5741.000000  108090  14.283226  0.758627
# 5  161390        한국타이어   5648.500000   51341   7.453306  0.820007
# 6  181710   NHN엔터테인먼트   2110.166667   78434  30.755864  0.827447
# 7  185750            종근당   3990.333333   40684  25.185866  2.470259
# 8  204210      모두투어리츠     85.166667    5335  40.802348  0.651359
# 9  207940  삼성바이오로직스   4644.166667   60099  89.790059  6.938551

# %%
merge_inner = pd.merge(df1, df2)
merge_inner
# Out:
#        id    stock_name          value   price          name           eps  \
# 0  130960        CJ E&M   58540.666667   98900        CJ E&M   6301.333333
# 1  139480        이마트  239230.833333  254500        이마트  18268.166667
# 2  145990        삼양사   82750.000000   82000        삼양사   5741.000000
# 3  185750        종근당   40293.666667  100500        종근당   3990.333333
# 4  204210  모두투어리츠    3093.333333    3475  모두투어리츠     85.166667
#
#       bps        per       pbr
# 0   54068  15.695091  1.829178
# 1  295780  13.931338  0.860437
# 2  108090  14.283226  0.758627
# 3   40684  25.185866  2.470259
# 4    5335  40.802348  0.651359

# %%
merge_outer = pd.merge(df1, df2, how ='outer', on ='id')
merge_outer
# Out:
#         id    stock_name          value     price              name  \
# 0   128940      한미약품   59385.666667  421000.0               NaN
# 1   130960        CJ E&M   58540.666667   98900.0            CJ E&M
# 2   136480           NaN            NaN       NaN              하림
# 3   138040           NaN            NaN       NaN    메리츠금융지주
# 4   138250    엔에스쇼핑   14558.666667   13200.0               NaN
# 5   139480        이마트  239230.833333  254500.0            이마트
# 6   142280  녹십자엠에스     468.833333   10200.0               NaN
# 7   145990        삼양사   82750.000000   82000.0            삼양사
# 8   161390           NaN            NaN       NaN        한국타이어
# 9   181710           NaN            NaN       NaN   NHN엔터테인먼트
# 10  185750        종근당   40293.666667  100500.0            종근당
# 11  192400    쿠쿠홀딩스  179204.666667  177500.0               NaN
# 12  199800          툴젠   -2514.333333  115400.0               NaN
# 13  204210  모두투어리츠    3093.333333    3475.0      모두투어리츠
# 14  207940           NaN            NaN       NaN  삼성바이오로직스
#
#              eps       bps        per       pbr
# 0            NaN       NaN        NaN       NaN
# 1    6301.333333   54068.0  15.695091  1.829178
# 2     274.166667    3551.0  11.489362  0.887074
# 3    2122.333333   14894.0   6.313806  0.899691
# 4            NaN       NaN        NaN       NaN
# 5   18268.166667  295780.0  13.931338  0.860437
# 6            NaN       NaN        NaN       NaN
# 7    5741.000000  108090.0  14.283226  0.758627
# 8    5648.500000   51341.0   7.453306  0.820007
# 9    2110.166667   78434.0  30.755864  0.827447
# 10   3990.333333   40684.0  25.185866  2.470259
# 11           NaN       NaN        NaN       NaN
# 12           NaN       NaN        NaN       NaN
# 13     85.166667    5335.0  40.802348  0.651359
# 14   4644.166667   60099.0  89.790059  6.938551

# %%
# 데이터프레임 합치기 - 왼쪽 데이터프레임 기준, 키 값 분리
# left 의 이름을 기준으로 배열이 된다

merge_left = pd.merge(df1, df2, how ='left', left_on ='stock_name', right_on ='name')
merge_left
# Out:
#      id_x    stock_name          value   price      id_y          name  \
# 0  128940      한미약품   59385.666667  421000       NaN           NaN
# 1  130960        CJ E&M   58540.666667   98900  130960.0        CJ E&M
# 2  138250    엔에스쇼핑   14558.666667   13200       NaN           NaN
# 3  139480        이마트  239230.833333  254500  139480.0        이마트
# 4  142280  녹십자엠에스     468.833333   10200       NaN           NaN
# 5  145990        삼양사   82750.000000   82000  145990.0        삼양사
# 6  185750        종근당   40293.666667  100500  185750.0        종근당
# 7  192400    쿠쿠홀딩스  179204.666667  177500       NaN           NaN
# 8  199800          툴젠   -2514.333333  115400       NaN           NaN
# 9  204210  모두투어리츠    3093.333333    3475  204210.0  모두투어리츠
#
#             eps       bps        per       pbr
# 0           NaN       NaN        NaN       NaN
# 1   6301.333333   54068.0  15.695091  1.829178
# 2           NaN       NaN        NaN       NaN
# 3  18268.166667  295780.0  13.931338  0.860437
# 4           NaN       NaN        NaN       NaN
# 5   5741.000000  108090.0  14.283226  0.758627
# 6   3990.333333   40684.0  25.185866  2.470259
# 7           NaN       NaN        NaN       NaN
# 8           NaN       NaN        NaN       NaN
# 9     85.166667    5335.0  40.802348  0.651359

# %%
merge_right = pd.merge(df1, df2, how ='right', left_on ='stock_name', right_on ='name')
merge_right
# Out:
#        id_x    stock_name          value     price    id_y              name  \
# 0  130960.0        CJ E&M   58540.666667   98900.0  130960            CJ E&M
# 1       NaN           NaN            NaN       NaN  136480              하림
# 2       NaN           NaN            NaN       NaN  138040    메리츠금융지주
# 3  139480.0        이마트  239230.833333  254500.0  139480            이마트
# 4  145990.0        삼양사   82750.000000   82000.0  145990            삼양사
# 5       NaN           NaN            NaN       NaN  161390        한국타이어
# 6       NaN           NaN            NaN       NaN  181710   NHN엔터테인먼트
# 7  185750.0        종근당   40293.666667  100500.0  185750            종근당
# 8  204210.0  모두투어리츠    3093.333333    3475.0  204210      모두투어리츠
# 9       NaN           NaN            NaN       NaN  207940  삼성바이오로직스
#
#             eps     bps        per       pbr
# 0   6301.333333   54068  15.695091  1.829178
# 1    274.166667    3551  11.489362  0.887074
# 2   2122.333333   14894   6.313806  0.899691
# 3  18268.166667  295780  13.931338  0.860437
# 4   5741.000000  108090  14.283226  0.758627
# 5   5648.500000   51341   7.453306  0.820007
# 6   2110.166667   78434  30.755864  0.827447
# 7   3990.333333   40684  25.185866  2.470259
# 8     85.166667    5335  40.802348  0.651359
# 9   4644.166667   60099  89.790059  6.938551

# %%
# 불린 인덱싱과 결합하여 원하는 데이터 찾기
price = df1[df1['price'] < 50000]
price
# Out:
#        id    stock_name         value  price
# 2  138250    엔에스쇼핑  14558.666667  13200
# 4  142280  녹십자엠에스    468.833333  10200
# 9  204210  모두투어리츠   3093.333333   3475

# %%
value = pd.merge(price, df2)
value
# Out:
#        id    stock_name        value  price          name        eps   bps  \
# 0  204210  모두투어리츠  3093.333333   3475  모두투어리츠  85.166667  5335
#
#          per       pbr
# 0  40.802348  0.651359

# %% [markdown]
# # 4-3 데이터프레임 결합
# - join() 메소드는 merge()메소드 기반으로 만들어졌기 때문에 동작방식이 비슷하지만 join() 메소드는 두 데이터프레임의 행 인덱스를 기준으로 결합하는 점에서 merge()와 차이가 있음
# - on-keyts 옵션을 설정하면 행 인덱스 대신 다른 열을 기준으로 결합

# %%
df1 = pd.read_excel('C:/sample_data/stock price.xlsx', index_col='id')
df2 = pd.read_excel('C:/sample_data/stock valuation.xlsx', index_col='id')
display(df1.head())
display(df1.head())
# Out:
#           stock_name          value   price
# id
# 128940      한미약품   59385.666667  421000
# 130960        CJ E&M   58540.666667   98900
# 138250    엔에스쇼핑   14558.666667   13200
# 139480        이마트  239230.833333  254500
# 142280  녹십자엠에스     468.833333   10200
#           stock_name          value   price
# id
# 128940      한미약품   59385.666667  421000
# 130960        CJ E&M   58540.666667   98900
# 138250    엔에스쇼핑   14558.666667   13200
# 139480        이마트  239230.833333  254500
# 142280  녹십자엠에스     468.833333   10200

# %%
df3=df1.join(df2) # 외부조인
df3
# Out:
#           stock_name          value   price          name           eps  \
# id
# 128940      한미약품   59385.666667  421000           NaN           NaN
# 130960        CJ E&M   58540.666667   98900        CJ E&M   6301.333333
# 138250    엔에스쇼핑   14558.666667   13200           NaN           NaN
# 139480        이마트  239230.833333  254500        이마트  18268.166667
# 142280  녹십자엠에스     468.833333   10200           NaN           NaN
# 145990        삼양사   82750.000000   82000        삼양사   5741.000000
# 185750        종근당   40293.666667  100500        종근당   3990.333333
# 192400    쿠쿠홀딩스  179204.666667  177500           NaN           NaN
# 199800          툴젠   -2514.333333  115400           NaN           NaN
# 204210  모두투어리츠    3093.333333    3475  모두투어리츠     85.166667
#
#              bps        per       pbr
# id
# 128940       NaN        NaN       NaN
# 130960   54068.0  15.695091  1.829178
# 138250       NaN        NaN       NaN
# 139480  295780.0  13.931338  0.860437
# 142280       NaN        NaN       NaN
# 145990  108090.0  14.283226  0.758627
# 185750   40684.0  25.185866  2.470259
# 192400       NaN        NaN       NaN
# 199800       NaN        NaN       NaN
# 204210    5335.0  40.802348  0.651359

# %%
df4=df1.join(df2, how = 'inner') # 외부조인
df4
# Out:
#           stock_name          value   price          name           eps  \
# id
# 130960        CJ E&M   58540.666667   98900        CJ E&M   6301.333333
# 139480        이마트  239230.833333  254500        이마트  18268.166667
# 145990        삼양사   82750.000000   82000        삼양사   5741.000000
# 185750        종근당   40293.666667  100500        종근당   3990.333333
# 204210  모두투어리츠    3093.333333    3475  모두투어리츠     85.166667
#
#            bps        per       pbr
# id
# 130960   54068  15.695091  1.829178
# 139480  295780  13.931338  0.860437
# 145990  108090  14.283226  0.758627
# 185750   40684  25.185866  2.470259
# 204210    5335  40.802348  0.651359

# %% [markdown]
# # 5 그룹연산
#
# - 복잡한 데이터를 어떤 기준에 따라 여러 그룹으로 나눠서 관찰하는 것도 데이터 분석에 필요할 수 있음
# - 특정 기준을 적용하여 몇 개으 ㅣ그룹을 ㅗ분할하여 처리하는 것을 그룹 연산이라고 함
# -그룹 연산은 데이터를 집계 변환 필터링을 하는데 효율적

# %%
import seaborn as sns

titanic = sns.load_dataset('titanic')
df = titanic.loc[:, ['age','sex', 'class','fare','survived']] 
df.head()
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
print('승객 수:', len(df))
# Out:
# 승객 수: 891

# %%
# class 열을 기준으로 분할 , class를 기준으로 각각 묶은 그룹
grouped = df.groupby(['class'])
print(grouped)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001BCCD3E1B80>
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\4276055945.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['class'])

# %%
# 그룹 객체를 iteration 으로 출력: head() 메소드로 첫 5행만을 출력
for key, group in grouped:
    print('* key :', key)
    print('* number :', len(group)) # en(group)은 현재 그룹의 크기, 즉 행의 개수를
    display(group.head())
    print('\n')
# Out:
# * key : ('First',)
# * number : 216
#      age     sex  class     fare  survived
# 1   38.0  female  First  71.2833         1
# 3   35.0  female  First  53.1000         1
# 6   54.0    male  First  51.8625         0
# 11  58.0  female  First  26.5500         1
# 23  28.0    male  First  35.5000         1
# * key : ('Second',)
# * number : 184
#      age     sex   class     fare  survived
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# 17   NaN    male  Second  13.0000         1
# 20  35.0    male  Second  26.0000         0
# 21  34.0    male  Second  13.0000         1
# * key : ('Third',)
# * number : 491
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 2  26.0  female  Third   7.9250         1
# 4  35.0    male  Third   8.0500         0
# 5   NaN    male  Third   8.4583         0
# 7   2.0    male  Third  21.0750         0

# %%
average = grouped.mean(numeric_only = True)
average # 1등석에 있는 사람들이 좀 많이 살아남은 것을 알 수 있다
# Out:
#               age       fare  survived
# class
# First   38.233441  84.154687  0.629630
# Second  29.877630  20.662183  0.472826
# Third   25.140620  13.675550  0.242363

# %%
# 연산 메소드 적용
cnt = grouped.count()
cnt
# Out:
#         age  sex  fare  survived
# class
# First   186  216   216       216
# Second  173  184   184       184
# Third   355  491   491       491

# %%
group3 = grouped.get_group('Third')
group3.head()
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\2500203070.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   group3 = grouped.get_group('Third')
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 2  26.0  female  Third   7.9250         1
# 4  35.0    male  Third   8.0500         0
# 5   NaN    male  Third   8.4583         0
# 7   2.0    male  Third  21.0750         0

# %%
# 위에는 튜플 형태였따

# %% [markdown]
# 여러 열을 기준으로 그룹화
# - 여러개의 기준값을 사용

# %%
# class 열, sex 열을 기준으로 분할
grouped_two = df.groupby(['class', 'sex'])
grouped_two
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\2653891627.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_two = df.groupby(['class', 'sex'])

# %%
for key, group in grouped_two:
    print('* key :', key)
    print('* number :', len(group)) # en(group)은 현재 그룹의 크기, 즉 행의 개수를
    display(group.head())
    print('\n')
# Out:
# * key : ('First', 'female')
# * number : 94
#      age     sex  class      fare  survived
# 1   38.0  female  First   71.2833         1
# 3   35.0  female  First   53.1000         1
# 11  58.0  female  First   26.5500         1
# 31   NaN  female  First  146.5208         1
# 52  49.0  female  First   76.7292         1
# * key : ('First', 'male')
# * number : 122
#      age   sex  class      fare  survived
# 6   54.0  male  First   51.8625         0
# 23  28.0  male  First   35.5000         1
# 27  19.0  male  First  263.0000         0
# 30  40.0  male  First   27.7208         0
# 34  28.0  male  First   82.1708         0
# * key : ('Second', 'female')
# * number : 76
#      age     sex   class     fare  survived
# 9   14.0  female  Second  30.0708         1
# 15  55.0  female  Second  16.0000         1
# 41  27.0  female  Second  21.0000         0
# 43   3.0  female  Second  41.5792         1
# 53  29.0  female  Second  26.0000         1
# * key : ('Second', 'male')
# * number : 108
#      age   sex   class  fare  survived
# 17   NaN  male  Second  13.0         1
# 20  35.0  male  Second  26.0         0
# 21  34.0  male  Second  13.0         1
# 33  66.0  male  Second  10.5         0
# 70  32.0  male  Second  10.5         0
# * key : ('Third', 'female')
# * number : 144
#      age     sex  class     fare  survived
# 2   26.0  female  Third   7.9250         1
# 8   27.0  female  Third  11.1333         1
# 10   4.0  female  Third  16.7000         1
# 14  14.0  female  Third   7.8542         0
# 18  31.0  female  Third  18.0000         0
# * key : ('Third', 'male')
# * number : 347
#      age   sex  class     fare  survived
# 0   22.0  male  Third   7.2500         0
# 4   35.0  male  Third   8.0500         0
# 5    NaN  male  Third   8.4583         0
# 7    2.0  male  Third  21.0750         0
# 12  20.0  male  Third   8.0500         0

# %%
average_two = grouped_two.mean(numeric_only=True)
display(average_two)
print('\n')
print(type(average_two))
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447
# <class 'pandas.core.frame.DataFrame'>

# %%
# grouped_two 그룹 객체에서 개별 그룹 선택하기
group3f = grouped_two.get_group(('Third', 'female'))
group3f.head()
# Out:
#      age     sex  class     fare  survived
# 2   26.0  female  Third   7.9250         1
# 8   27.0  female  Third  11.1333         1
# 10   4.0  female  Third  16.7000         1
# 14  14.0  female  Third   7.8542         0
# 18  31.0  female  Third  18.0000         0

# %% [markdown]
# 5-2 그룹 연산 메소드 (적용 - 결합 단계)

# %%
grouped = df.groupby(['class'])
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\1947293847.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['class'])

# %%
# 각 그룹에 대한 모든 열의 표준 편차를 집계하여 데이터프레임으로 변환
std_all = grouped.std
std_all
# Out:
# <bound method GroupBy.std of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x000001BCCD27DEE0>>

# %%
std_fare= grouped['fare'].std(numeric_only=True) 
# umeric_only=True는 연산 대상을 숫자형 데이터로 제한하여 의미 있는 결과를 얻거나 성능 향상을 위해 사용되는 옵션
std_fare
# Out:
# class
# First     78.380373
# Second    13.417399
# Third     11.778142
# Name: fare, dtype: float64

# %% [markdown]
# - 집계 연산을 처리하는 사용자 정의 함수를 객체에 적용하려면 agg()메소드를 사용

# %%
# 그룹 객체에 agg() 메소드를 적용 - 사용자 정의 함수를 인수로 전달
def min_max(x):   # 최대값 - 최소값 
    return x.max() - x.min()

# %%
agg_minmax = grouped[['fare','age']].agg(min_max)
agg_minmax
# Out:
#             fare    age
# class
# First   512.3292  79.08
# Second   73.5000  69.33
# Third    69.5500  73.58

# %%
# 여러 함수를 각 열에 동일하게 적용하여 집계
agg_all = grouped.agg(['min','max'])
agg_all
# Out:
#          age           sex       fare           survived
#          min   max     min   max  min       max      min max
# class
# First   0.92  80.0  female  male  0.0  512.3292        0   1
# Second  0.67  70.0  female  male  0.0   73.5000        0   1
# Third   0.42  74.0  female  male  0.0   69.5500        0   1

# %%
agg_sep = grouped.agg({'fare':['min','max'], 'age': 'mean'})
agg_sep
# Out:
#        fare                  age
#         min       max       mean
# class
# First   0.0  512.3292  38.233441
# Second  0.0   73.5000  29.877630
# Third   0.0   69.5500  25.140620

# %%
df = titanic.loc[:, ['age','sex', 'class','fare','survived']] 
df.head()
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
# class 열을 기준으로 분할
grouped = df.groupby(['class'])
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\3388263704.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['class'])

# %%
age_mean = grouped['age'].mean()
age_mean
# Out:
# class
# First     38.233441
# Second    29.877630
# Third     25.140620
# Name: age, dtype: float64

# %%
age_std = grouped['age'].std()
age_std
# Out:
# class
# First     14.802856
# Second    14.001077
# Third     12.495398
# Name: age, dtype: float64

# %%
for key, group in grouped['age']:
    group_zscore = (group - age_mean.loc[key]) / age_std.loc[key]
    print('* origin :', key)
    display(group.head(3))
    display(group_zscore.head(3))
    print('\n')
# Out:
# * origin : ('First',)
# 1    38.0
# 3    35.0
# 6    54.0
# Name: age, dtype: float64
# 1   -0.015770
# 3   -0.218434
# 6    1.065103
# Name: age, dtype: float64
# * origin : ('Second',)
# 9     14.0
# 15    55.0
# 17     NaN
# Name: age, dtype: float64
# 9    -1.134029
# 15    1.794317
# 17         NaN
# Name: age, dtype: float64
# * origin : ('Third',)
# 0    22.0
# 2    26.0
# 4    35.0
# Name: age, dtype: float64
# 0   -0.251342
# 2    0.068776
# 4    0.789041
# Name: age, dtype: float64

# %% [markdown]
# - transform() 메소드를 사용 'age' 열의 데이터를 z-score로 직접 변환

# %%
# z-score를 계산하는 사용자 함수 정의
def z_score(x):
    return (x - x.mean()) / x.std()

# %%
# transform() 메소드를 이용하여 age열의 데이터를 z-score로 변환

age_zscore = grouped['age'].transform(z_score)
age_zscore
# Out:
# 0     -0.251342
# 1     -0.015770
# 2      0.068776
# 3     -0.218434
# 4      0.789041
#          ...
# 886   -0.205529
# 887   -1.299306
# 888         NaN
# 889   -0.826424
# 890    0.548953
# Name: age, Length: 891, dtype: float64

# %%
age_zscore.loc[[1 , 9 , 0]] # 1,2,3 그룹의 첫 데이터 확인
# Out:
# 1   -0.015770
# 9   -1.134029
# 0   -0.251342
# Name: age, dtype: float64

# %%
len(age_zscore)
# Out:
# 891

# %%
age_zscore.loc[0:9]
# Out:
# 0   -0.251342
# 1   -0.015770
# 2    0.068776
# 3   -0.218434
# 4    0.789041
# 5         NaN
# 6    1.065103
# 7   -1.851931
# 8    0.148805
# 9   -1.134029
# Name: age, dtype: float64

# %%
type(age_zscore)
# Out:
# pandas.core.series.Series

# %% [markdown]
# 그룹 객체 필터링

# %%
df.head()
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
# class 열을 기준으로 분할
grouped = df.groupby(['class'])

# 데이터 개수가 200개 이상인 그룹만을 필터링하여 데이터프레임으로 변환
grouped_filter = grouped.filter(lambda x : len(x) >= 200)
grouped_filter.head(100)
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\166183846.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['class'])
#       age     sex  class      fare  survived
# 0    22.0    male  Third    7.2500         0
# 1    38.0  female  First   71.2833         1
# 2    26.0  female  Third    7.9250         1
# 3    35.0  female  First   53.1000         1
# 4    35.0    male  Third    8.0500         0
# ..    ...     ...    ...       ...       ...
# 113  20.0  female  Third    9.8250         0
# 114  17.0  female  Third   14.4583         0
# 115  21.0    male  Third    7.9250         0
# 116  70.5    male  Third    7.7500         0
# 118  24.0    male  First  247.5208         0
#
# [100 rows x 5 columns]

# %%
len(df)
# Out:
# 891

# %%
grouped_filter['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second      0
# Name: count, dtype: int64

# %%
grouped.mean(numeric_only =True)
# Out:
#               age       fare  survived
# class
# First   38.233441  84.154687  0.629630
# Second  29.877630  20.662183  0.472826
# Third   25.140620  13.675550  0.242363

# %%
age_filter = grouped.filter(lambda x : x['age'].mean() < 30)
age_filter.head()
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 2  26.0  female  Third   7.9250         1
# 4  35.0    male  Third   8.0500         0
# 5   NaN    male  Third   8.4583         0
# 7   2.0    male  Third  21.0750         0

# %%
# 집계 : 각 그룹별 요약 통계정보를 집계
age_grouped = grouped.apply(lambda x : x.describe())
age_grouped
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\3010650451.py:2: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   age_grouped = grouped.apply(lambda x : x.describe())
#                      age        fare    survived
# class
# First  count  186.000000  216.000000  216.000000
#        mean    38.233441   84.154687    0.629630
#        std     14.802856   78.380373    0.484026
#        min      0.920000    0.000000    0.000000
#        25%     27.000000   30.923950    0.000000
#        50%     37.000000   60.287500    1.000000
#        75%     49.000000   93.500000    1.000000
#        max     80.000000  512.329200    1.000000
# Second count  173.000000  184.000000  184.000000
#        mean    29.877630   20.662183    0.472826
#        std     14.001077   13.417399    0.500623
#        min      0.670000    0.000000    0.000000
#        25%     23.000000   13.000000    0.000000
#        50%     29.000000   14.250000    0.000000
#        75%     36.000000   26.000000    1.000000
#        max     70.000000   73.500000    1.000000
# Third  count  355.000000  491.000000  491.000000
#        mean    25.140620   13.675550    0.242363
#        std     12.495398   11.778142    0.428949
#        min      0.420000    0.000000    0.000000
#        25%     18.000000    7.750000    0.000000
#        50%     24.000000    8.050000    0.000000
#        75%     32.000000   15.500000    0.000000
#        max     74.000000   69.550000    1.000000

# %%
age_zscore = grouped['age'].apply(z_score) # 기본값 axis = 0
age_zscore.head()
# Out:
# class
# First  1    -0.015770
#        3    -0.218434
#        6     1.065103
#        11    1.335321
#        23   -0.691315
# Name: age, dtype: float64

# %%
# class 열, sex 열을 기준으로 분할
grouped = df.groupby(['class' ,'sex'])
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\1913361915.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['class' ,'sex'])

# %%
# 그룹 객체에 연산 메서드 적용
gdf = grouped.mean()
gdf
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447

# %%
gdf.index
# Out:
# MultiIndex([( 'First', 'female'),
#             ( 'First',   'male'),
#             ('Second', 'female'),
#             ('Second',   'male'),
#             ( 'Third', 'female'),
#             ( 'Third',   'male')],
#            names=['class', 'sex'])

# %%
# class 값이 First 인 행을 선택하여 출력 
gdf.loc['First']
# Out:
#               age        fare  survived
# sex
# female  34.611765  106.125798  0.968085
# male    41.281386   67.226127  0.368852

# %%
# # class 값이 First이고, sex 값이 female인 행을 선택하여 출력
gdf.loc[('First','female')]
# Out:
# age          34.611765
# fare        106.125798
# survived      0.968085
# Name: (First, female), dtype: float64

# %% [markdown]
# # 7 피벗
#
# - 판다스 피봇테이블 함수는 엑셀의 피벗테이블과 비슷한 기능을 처리
# - 피벗테이블을 구성하는 4가지 요소(행 인덱스, 열 인덱스 데이터 값 데이터 집계함수) 에 적용할 데이터프레임을 각각 지정하여 함수 인자로 전달

# %%
# 행 열 값 집계에 사용할 열을 1개씩 지정 - 평균합계
pdf1 = pd.pivot_table(df,
                      index = 'class',
                      columns = 'sex',
                      values = 'age',
                      aggfunc = 'mean')

pdf1
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\1787163436.py:2: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pdf1 = pd.pivot_table(df,
# sex        female       male
# class
# First   34.611765  41.281386
# Second  28.722973  30.740707
# Third   21.750000  26.507589

# %%
# 값에 적용하는 집계 함수를 2개 이상 지정 가능 - 생존율, 생존자 수 집계
# 행 열 값 집계에 사용할 열을 1개씩 지정 - 평균합계
pdf2 = pd.pivot_table(df,
                      index = 'class',
                      columns = 'sex',
                      values = 'age',
                      aggfunc = ['mean','sum'])

pdf2
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\670280459.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pdf2 = pd.pivot_table(df,
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\670280459.py:3: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pdf2 = pd.pivot_table(df,
#              mean                sum
# sex        female       male  female     male
# class
# First   34.611765  41.281386  2942.0  4169.42
# Second  28.722973  30.740707  2125.5  3043.33
# Third   21.750000  26.507589  2218.5  6706.42

# %%
pdf2.columns
# Out:
# MultiIndex([('mean', 'female'),
#             ('mean',   'male'),
#             ( 'sum', 'female'),
#             ( 'sum',   'male')],
#            names=[None, 'sex'])

# %%
pdf3 = pd.pivot_table(df,
                      index = ['class','sex'],
                      columns = 'survived',
                      values = ['age', 'fare'],
                      aggfunc = ['mean','max'])

pdf3
# Out:
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\337875488.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pdf3 = pd.pivot_table(df,
# C:\Users\705-8\AppData\Local\Temp\ipykernel_1412\337875488.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pdf3 = pd.pivot_table(df,
#                     mean                                      max        \
#                      age                   fare               age
# survived               0          1           0           1     0     1
# class  sex
# First  female  25.666667  34.939024  110.604167  105.978159  50.0  63.0
#        male    44.581967  36.248000   62.894910   74.637320  71.0  80.0
# Second female  36.000000  28.080882   18.250000   22.288989  57.0  55.0
#        male    33.369048  16.022000   19.488965   21.095100  70.0  62.0
# Third  female  23.818182  19.329787   19.773093   12.464526  48.0  63.0
#        male    27.255814  22.274211   12.204469   15.579696  74.0  45.0
#
#
#                  fare
# survived            0         1
# class  sex
# First  female  151.55  512.3292
#        male    263.00  512.3292
# Second female   26.00   65.0000
#        male     73.50   39.0000
# Third  female   69.55   31.3875
#        male     69.55   56.4958

# %%
# 여기까지 ,,
